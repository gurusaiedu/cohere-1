# %% [markdown]
# <a href="https://colab.research.google.com/github/gurusaiedu/cohere-1/blob/main/prompt_templets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 816.1/816.1 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 13.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.1/242.1 kB 15.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.2 MB/s eta 0:00:00
# ...

# %%
pip install cohere
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.2/52.2 kB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 30.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: importlib_metadata
#     Found existing installation: importlib-metadata 7.0.1
#     Uninstalling importlib-metadata-7.0.1:
#       Successfully uninstalled importlib-metadata-7.0.1
# ...

# %%
from langchain.callbacks import StreamingStdOutCallbackHandler
from langchain.chains import LLMChain
from langchain.chat_models import ChatCohere
from langchain.prompts import PromptTemplate

# %%
cohere_api_key="btu0gWrLzedOkMOrjGC1k6gEhVbIcR0GdsrNlT24"

# %%
llm=ChatCohere(cohere_api_key=cohere_api_key,
               temperature=0)

# %%
response=llm.predict("hi")
print(response)
# Out:
# Hello! What can I help you with today?
# I'm happy to provide you with thorough responses, and assist you with any questions or queries you have.
#
# Let me know if there's anything I can help with, and please let me know if you require assistance in a particular format, and I'll be happy to adapt my responses to suit your needs.

# %%
help(llm)
# Out:
# Help on ChatCohere in module langchain_community.chat_models.cohere object:
#
# class ChatCohere(langchain_core.language_models.chat_models.BaseChatModel, langchain_community.llms.cohere.BaseCohere)
#  |  ChatCohere(*, client: Any = None, async_client: Any = None, model: Optional[str] = None, temperature: float = 0.75, cohere_api_key: Optional[str] = None, stop: Optional[List[str]] = None, streaming: bool = False, user_agent: str = 'langchain', name: Optional[str] = None, cache: Optional[bool] = None, verbose: bool = None, callbacks: Union[List[langchain_core.callbacks.base.BaseCallbackHandler], langchain_core.callbacks.base.BaseCallbackManager, NoneType] = None, callback_manager: Optional[langchain_core.callbacks.base.BaseCallbackManager] = None, tags: Optional[List[str]] = None, metadata: Optional[Dict[str, Any]] = None) -> None
#  |
#  |  `Cohere` chat large language models.
#  |
#  |  To use, you should have the ``cohere`` python package installed, and the
# ...

# %%
prompt_templet_string="consider your good programmder \
develop a java working program for {question} \
"

# %%
prompt_templet= PromptTemplate(template=prompt_templet_string, input_variables=['question'])
prompt_templet
# Out:
# PromptTemplate(input_variables=['question'], template='consider your good programmder develop a java working program for {question} ')

# %%
prompt_templet.input_variables
# Out:
# ['question']

# %%
llm_chain=LLMChain(prompt=prompt_templet,llm=llm)
question="positive or negative of a give number "

response=llm_chain.run(question)

print(response)
# Out:
# Here is a sample program written in Java that determines the sign of a given number:
# ```java
# import java.util.Scanner;
#
# public class SignOfNumber {
#     public static void main(String[] args) {
#         Scanner scanner = new Scanner(System.in);
#         System.out.print("Enter a number: ");
#         double number = scanner.nextDouble();
#
#         if (number > 0) {
#             System.out.println("The sign of the number is positive.");
#         } else if (number < 0) {
#             System.out.println("The sign of the number is negative.");
#         } else {
#             System.out.println("The sign of the number is zero.");
#         }
#
#         scanner.close();
#     }
# }
# ```
#
# This program utilizes a `Scanner` to obtain a number from the user and determines its sign by employing conditional statements. It then prints out the result, whether it is positive, negative, or zero.
#
# ...

# %% [markdown]
# **to pass multiput inputs**

# %%
llm=ChatCohere(cohere_api_key=cohere_api_key,
               temperature=0)

# %%
prompt_templet_string1="let's consider your good programmder, \
develop a working {language} program for {question} \
"

# %%
from langchain.prompts import ChatPromptTemplate
prompt_templet= ChatPromptTemplate.from_template(prompt_templet_string1)

 #(template=prompt_templet_string, input_variables=['question'])
prompt_templet
# Out:
# ChatPromptTemplate(input_variables=['language', 'question'], messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['language', 'question'], template="let's consider your good programmder, develop a working {language} program for {question} "))])

# %%
prompt_templet.input_variables
# Out:
# ['language', 'question']

# %%
language="java"
question="positive or negative of a give number "

customer_messages=prompt_templet.format_messages(language=language,question=question)
customer_messages
# Out:
# [HumanMessage(content="let's consider your good programmder, develop a working java program for positive or negative of a give number  ")]

# %%
reponse=llm(customer_messages)
print(reponse.content)
# Out:
# Here is a simple Java program that computes the positive and negative of a given number:
# ```java
# import java.util.Scanner;
#
# public class NumberProcessor {
#
#     public static void main(String[] args) {
#         Scanner scanner = new Scanner(System.in);
#         System.out.print("Enter a number: ");
#         double number = scanner.nextDouble();
#
#         double positive = 0;
#         if (number > 0) {
#             positive = number;
#         } else {
#             positive = -number;
#         }
#
#         System.out.println("The positive of " + number + " is: " + positive);
#     }
# }
# ```
#
# This Java program defines a `main` function that prompts the user to enter a number. It reads the user's input using the `nextDouble()` function of the `Scanner` class. The program then performs the following:
# ...
